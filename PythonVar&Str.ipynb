# %%
# ===============================
# PYTHON BASICS – VARIABLES & STRINGS
# ===============================

# %%
# Q1.
# Assign your name to a variable called `name`.
# Print the first character and the last character of the name
# WITHOUT using hardcoded indexes like [0] or [-1].

name = 'jayanth'
print(name[0], name[-1])
# Out:
# j h

# %%
# Q2.
# Create two variables:
#   a = "10"
#   b = 5
# Try to add them and store the result in `result`.
# Fix the code so that the output becomes 15 (number), not "105".

a='10'
b=5
print(int(a)+b)
# Out:
# 15

# %%
# Q3.
# Given the string:
#   s = "python programming"
# Print:
#   1) The length of the string
#   2) The word "python"
#   3) The word "programming"
# WITHOUT using split().

s = "python programming"
print(len(s))
print(s[0:6])
print(s[7:])
# Out:
# 18
# python
# programming

# %%
# Q4.
# Create a variable `text = "  Hello World  "`
# Remove the extra spaces from both sides
# Convert the result to lowercase
# Store the final output in a variable called `clean_text`.

text = "  Hello World  "
print(text.strip().lower())
# Out:
# hello world

# %%
# Q5.
# Given:
#   x = "5"
#   y = "3"
# Print the result of x + y
# Then print the result of int(x) + int(y)
# Observe and explain (in comments) why the outputs are different.

x = "5"
y = "3"
print(x+y)
print(int(x)+int(y))
#case-1 string concating
#case-2 typecasting
# Out:
# 53
# 8

# %%
# Q6.
# Create a string variable `word = "banana"`
# Count how many times the letter 'a' appears
# WITHOUT using count().

word = "banana"
ct=0
for w in word:
  if w == 'a':
    ct+=1

print(ct)
# Out:
# 3

# %%
# Q8.
# Create a variable `msg = "Python"`
# Reverse the string and store it in `rev`
# WITHOUT using loops and WITHOUT using reversed().

var = 'Python'
rev = var[::-1]
print(rev)
# Out:
# nohtyP

# %%
# Q9.
# Given:
#   a = "Hello"
#   b = a
# Change `a` to "Hi"
# Print both a and b
# Observe and explain (in comments) why b did or did not change.

a = "Hello"
b = a
a='Hi'
a,b
# Out:
# ('Hi', 'Hello')

# %%
# Q10. (THINK CAREFULLY)
# Predict the output BEFORE running the code:
#   x = "hello"
#   y = "hello"
#   print(x is y)
# Then run it.
# Write in comments whether the result matched your expectation and WHY.

x= "hello"
y= "Hello"
print(x is y)
# Out:
# False
